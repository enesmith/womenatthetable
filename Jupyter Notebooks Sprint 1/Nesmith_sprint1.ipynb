# %%
# import pandas package

# %%
import pandas as pd

# %%
# load in COMPAS data

# %%
data = pd.read_csv("https://raw.githubusercontent.com/propublica/compas-analysis/master/compas-scores-raw.csv")

# %%
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %%
data.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ScaleSet_ID            ScaleSet  \
# 0          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 1          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 2          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 3          Male        Caucasian    09/16/84           22  Risk and Prescreen
# 4          Male        Caucasian    09/16/84           22  Risk and Prescreen
#
#   AssessmentReason Language LegalStatus CustodyStatus MaritalStatus  \
# 0           Intake  English    Pretrial   Jail Inmate        Single
# 1           Intake  English    Pretrial   Jail Inmate        Single
# 2           Intake  English    Pretrial   Jail Inmate        Single
# 3           Intake  English    Pretrial   Jail Inmate       Married
# 4           Intake  English    Pretrial   Jail Inmate       Married
#
#   Screening_Date  RecSupervisionLevel RecSupervisionLevelText  Scale_ID  \
# 0    1/1/13 0:00                    1                     Low         7
# 1    1/1/13 0:00                    1                     Low         8
# 2    1/1/13 0:00                    1                     Low        18
# 3    1/1/13 0:00                    1                     Low         7
# 4    1/1/13 0:00                    1                     Low         8
#
#                  DisplayText  RawScore  DecileScore ScoreText AssessmentType  \
# 0           Risk of Violence     -2.08            4       Low            New
# 1         Risk of Recidivism     -1.06            2       Low            New
# 2  Risk of Failure to Appear     15.00            1       Low            New
# 3           Risk of Violence     -2.84            2       Low            New
# 4         Risk of Recidivism     -1.50            1       Low            New
#
#    IsCompleted  IsDeleted
# 0            1          0
# 1            1          0
# 2            1          0
# 3            1          0
# 4            1          0

# %%
# !pip install aif360;
# !pip install fairlearn;
# !pip install aif360[AdversarialDebiasing]
# Out:
# Requirement already satisfied: aif360 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: matplotlib in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360) (3.4.3)
# Requirement already satisfied: pandas>=0.24.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360) (1.3.4)
# Requirement already satisfied: scipy<1.6.0,>=1.2.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360) (1.5.4)
# Requirement already satisfied: numpy>=1.16 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.22.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360) (0.24.2)
# Requirement already satisfied: tempeh in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360) (0.1.12)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->aif360) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->aif360) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->aif360) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.1->aif360) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.1->aif360) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360) (1.3.1)
# Requirement already satisfied: shap in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tempeh->aif360) (0.40.0)
# Requirement already satisfied: requests in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tempeh->aif360) (2.26.0)
# Requirement already satisfied: memory-profiler in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tempeh->aif360) (0.60.0)
# Requirement already satisfied: pytest in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tempeh->aif360) (6.2.4)
# Requirement already satisfied: psutil in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from memory-profiler->tempeh->aif360) (5.8.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360) (21.2.0)
# Requirement already satisfied: iniconfig in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360) (1.1.1)
# Requirement already satisfied: packaging in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360) (21.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360) (1.10.0)
# Requirement already satisfied: toml in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360) (0.10.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests->tempeh->aif360) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests->tempeh->aif360) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests->tempeh->aif360) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests->tempeh->aif360) (2.0.4)
# Requirement already satisfied: cloudpickle in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360) (2.0.0)
# Requirement already satisfied: slicer==0.0.7 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360) (0.0.7)
# Requirement already satisfied: tqdm>4.25.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360) (4.62.3)
# Requirement already satisfied: numba in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360) (0.54.1)
# Requirement already satisfied: setuptools in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from numba->shap->tempeh->aif360) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from numba->shap->tempeh->aif360) (0.37.0)
# Requirement already satisfied: fairlearn in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (0.7.0)
# Requirement already satisfied: pandas>=0.25.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from fairlearn) (1.3.4)
# Requirement already satisfied: scikit-learn>=0.22.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from fairlearn) (0.24.2)
# Requirement already satisfied: scipy>=1.4.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from fairlearn) (1.5.4)
# Requirement already satisfied: numpy>=1.17.2 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from fairlearn) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.1->fairlearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.1->fairlearn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.25.1->fairlearn) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.1->fairlearn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.1->fairlearn) (1.1.0)
# Requirement already satisfied: aif360[AdversarialDebiasing] in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (0.4.0)
# Requirement already satisfied: pandas>=0.24.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360[AdversarialDebiasing]) (1.3.4)
# Requirement already satisfied: scikit-learn>=0.22.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360[AdversarialDebiasing]) (0.24.2)
# Requirement already satisfied: tempeh in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360[AdversarialDebiasing]) (0.1.12)
# Requirement already satisfied: numpy>=1.16 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360[AdversarialDebiasing]) (1.20.3)
# Requirement already satisfied: scipy<1.6.0,>=1.2.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360[AdversarialDebiasing]) (1.5.4)
# Requirement already satisfied: matplotlib in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from aif360[AdversarialDebiasing]) (3.4.3)
# Collecting tensorflow>=1.13.1
#   Downloading tensorflow-2.7.1-cp39-cp39-macosx_10_11_x86_64.whl (212.7 MB)
#      |████████████████████████████████| 212.7 MB 6.3 kB/s  eta 0:00:01    |███▎                            | 22.0 MB 36.5 MB/s eta 0:00:06     |██████████████▌                 | 96.4 MB 40.8 MB/s eta 0:00:03     |█████████████████               | 113.5 MB 10.4 MB/s eta 0:00:10     |████████████████████▌           | 136.5 MB 25.5 MB/s eta 0:00:03     |██████████████████████████▏     | 173.7 MB 23.8 MB/s eta 0:00:02     |████████████████████████████▌   | 189.5 MB 31.1 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->aif360[AdversarialDebiasing]) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->aif360[AdversarialDebiasing]) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->aif360[AdversarialDebiasing]) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.1->aif360[AdversarialDebiasing]) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.1->aif360[AdversarialDebiasing]) (1.1.0)
# Collecting libclang>=9.0.1
#   Downloading libclang-13.0.0-py2.py3-none-macosx_10_9_x86_64.whl (13.0 MB)
#      |████████████████████████████████| 13.0 MB 28.3 MB/s eta 0:00:01
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.43.0-cp39-cp39-macosx_10_10_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 29.3 MB/s eta 0:00:01
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 23.1 MB/s eta 0:00:01
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.4-cp39-cp39-macosx_10_9_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 49.8 MB/s eta 0:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 8.6 MB/s  eta 0:00:01
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 37.1 MB/s eta 0:00:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (0.37.0)
# Collecting tensorflow>=1.13.1
#   Downloading tensorflow-2.7.0-cp39-cp39-macosx_10_11_x86_64.whl (207.1 MB)
#      |████████████████████████████████| 207.1 MB 28.5 MB/s eta 0:00:01   |▉                               | 5.2 MB 29.9 MB/s eta 0:00:07     |█▊                              | 10.9 MB 29.9 MB/s eta 0:00:07     |██████████████████████████▏     | 169.6 MB 14.7 MB/s eta 0:00:03     |████████████████████████████▏   | 182.5 MB 17.4 MB/s eta 0:00:02
#   Downloading tensorflow-2.6.3-cp39-cp39-macosx_10_11_x86_64.whl (204.6 MB)
#      |████████████████████████████████| 204.6 MB 100 kB/s  eta 0:00:01    |█████████▊                      | 62.3 MB 23.2 MB/s eta 0:00:07     |███████████████▍                | 98.4 MB 7.5 MB/s eta 0:00:15     |████████████████████████████▊   | 183.5 MB 31.7 MB/s eta 0:00:01     |██████████████████████████████▊ | 196.6 MB 11.3 MB/s eta 0:00:01
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Downloading tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 30.4 MB/s eta 0:00:01
# Collecting numpy>=1.16
#   Downloading numpy-1.19.5-cp39-cp39-macosx_10_9_x86_64.whl (15.6 MB)
#      |████████████████████████████████| 15.6 MB 14.1 MB/s eta 0:00:01
# Requirement already satisfied: wrapt~=1.12.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (1.12.1)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting gast==0.4.0
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting absl-py~=0.10
#   Downloading absl_py-0.15.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 45.8 MB/s eta 0:00:01
# Collecting clang~=5.0
#   Downloading clang-5.0.tar.gz (30 kB)
# Requirement already satisfied: typing-extensions<3.11,>=3.7 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.10.0.2)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 8.1 MB/s  eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 3.9 MB/s  eta 0:00:01
# Collecting six>=1.5
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting h5py~=3.1.0
#   Downloading h5py-3.1.0-cp39-cp39-macosx_10_9_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 33.3 MB/s eta 0:00:01
# Collecting keras<2.7,>=2.6.0
#   Downloading keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 34.7 MB/s eta 0:00:01
# Collecting tensorboard<2.7,>=2.6.0
#   Downloading tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 13.6 MB/s eta 0:00:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 21.2 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.26.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (58.0.4)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 33.9 MB/s eta 0:00:01     |█▍                              | 153 kB 33.9 MB/s eta 0:00:01
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.0.2)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 17.2 MB/s eta 0:00:01
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      |████████████████████████████████| 152 kB 31.9 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 37.3 MB/s eta 0:00:01
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.6.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 9.5 MB/s  eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.7,>=2.6.0->tensorflow>=1.13.1->aif360[AdversarialDebiasing]) (3.2)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 49.6 MB/s eta 0:00:01
# Requirement already satisfied: cycler>=0.10 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360[AdversarialDebiasing]) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360[AdversarialDebiasing]) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360[AdversarialDebiasing]) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->aif360[AdversarialDebiasing]) (3.0.4)
# Requirement already satisfied: shap in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tempeh->aif360[AdversarialDebiasing]) (0.40.0)
# Requirement already satisfied: memory-profiler in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tempeh->aif360[AdversarialDebiasing]) (0.60.0)
# Requirement already satisfied: pytest in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from tempeh->aif360[AdversarialDebiasing]) (6.2.4)
# Requirement already satisfied: psutil in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from memory-profiler->tempeh->aif360[AdversarialDebiasing]) (5.8.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360[AdversarialDebiasing]) (21.2.0)
# Requirement already satisfied: iniconfig in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360[AdversarialDebiasing]) (1.1.1)
# Requirement already satisfied: packaging in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360[AdversarialDebiasing]) (21.0)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360[AdversarialDebiasing]) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360[AdversarialDebiasing]) (1.10.0)
# Requirement already satisfied: toml in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from pytest->tempeh->aif360[AdversarialDebiasing]) (0.10.2)
# Requirement already satisfied: slicer==0.0.7 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360[AdversarialDebiasing]) (0.0.7)
# Requirement already satisfied: numba in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360[AdversarialDebiasing]) (0.54.1)
# Requirement already satisfied: tqdm>4.25.0 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360[AdversarialDebiasing]) (4.62.3)
# Requirement already satisfied: cloudpickle in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from shap->tempeh->aif360[AdversarialDebiasing]) (2.0.0)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in /Users/elisabethnesmith/opt/anaconda3/lib/python3.9/site-packages (from numba->shap->tempeh->aif360[AdversarialDebiasing]) (0.37.0)
# Building wheels for collected packages: clang, termcolor
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30692 sha256=8ad2169ac0519c59985f87a25cfb79be82a3521e8011cf818dd12b7d7ae71b9e
#   Stored in directory: /Users/elisabethnesmith/Library/Caches/pip/wheels/3a/ce/7a/27094f689461801c934296d07078773603663dfcaca63bb064
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=5bf4f6e2a41dc6ad0f9de782f34b8e8e9420f03de2f56b7bab9681c5742d36f6
#   Stored in directory: /Users/elisabethnesmith/Library/Caches/pip/wheels/b6/0d/90/0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built clang termcolor
# Installing collected packages: six, pyasn1, numpy, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-estimator, tensorboard, opt-einsum, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, clang, astunparse, tensorflow
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Uninstalling numpy-1.20.3:
#       Successfully uninstalled numpy-1.20.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.2.1
#     Uninstalling h5py-3.2.1:
#       Successfully uninstalled h5py-3.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.3.0 requires daal==2021.2.3, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# Successfully installed absl-py-0.15.0 astunparse-1.6.3 cachetools-4.2.4 clang-5.0 flatbuffers-1.12 gast-0.4.0 google-auth-1.35.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.43.0 h5py-3.1.0 keras-2.6.0 keras-preprocessing-1.1.2 markdown-3.3.6 numpy-1.19.5 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.8 six-1.15.0 tensorboard-2.6.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.6.3 tensorflow-estimator-2.6.0 termcolor-1.1.0

# %%
#@title Import statements

# import statements
# create simple model using logistic regression
# evaluate model on those metrics

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from sklearn.compose import make_column_transformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, plot_roc_curve, recall_score, precision_score

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.preprocessing import OneHotEncoder

from aif360.datasets import BinaryLabelDataset
from aif360.algorithms.inprocessing import MetaFairClassifier

from aif360.sklearn.preprocessing import ReweighingMeta
from aif360.sklearn.inprocessing import AdversarialDebiasing
from aif360.sklearn.postprocessing import CalibratedEqualizedOdds, PostProcessingMeta
from aif360.sklearn.datasets import fetch_german
from aif360.sklearn.metrics import disparate_impact_ratio, average_odds_error, generalized_fpr, average_odds_difference
from aif360.sklearn.metrics import generalized_fnr, difference, statistical_parity_difference, equal_opportunity_difference, generalized_entropy_error

from IPython.display import Markdown, display
